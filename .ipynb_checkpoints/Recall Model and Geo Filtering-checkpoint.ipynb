# %%
import pandas as pd
import numpy as np
import os

# %%
# os.chdir('C:/Users/Axe-Yue-CHEN/Desktop/Online-Food-Merchant-Recommendation-Based-on-the-Meituan-Waimai-Application')

# %% [markdown]
# # 1 Data Preparing

# %% [markdown]
# ## 1.1 Read Data

# %%
# read user

# %%
path = './原数据-20210301-20210328/users.txt'
users = pd.read_csv(path, sep = "\t")

# %%
users['avg_pay_amt'].apply(lambda x: str(x).split(','))
# Out:
# 0         [[36, 49)]
# 1         [[49, 65)]
# 2              [<29]
# 3         [[49, 65)]
# 4         [[36, 49)]
#              ...
# 199995    [[36, 49)]
# 199996        [>=65]
# 199997    [[36, 49)]
# 199998         [<29]
# 199999         [<29]
# Name: avg_pay_amt, Length: 200000, dtype: object

# %%
# read pois
path = './原数据-20210301-20210328/pois.txt'
pois = pd.read_csv(path, sep = "\t")

# %%
# read orders

# %%
path = './原数据-20210301-20210328/orders_train.txt'
orders_train = pd.read_csv(path, sep = "\t")
# path = './dat/order_train_sampling.csv'
# orders_train = pd.read_csv(path)

# %%
orders_train.head()
# orders_train
# Out:
#    user_id  wm_order_id  wm_poi_id  aor_id order_price_interval  \
# 0   120037            0       1806       0                  <29
# 1   135109            1        970       6                 >=65
# 2   146736            2       1945       6              [29,36)
# 3    83644            3        708       6                 >=65
# 4   117903            4       2366       6              [29,36)
#
#    order_timestamp  ord_period_name order_scene_name  aoi_id  \
# 0       1614557985                0               未知     0.0
# 1       1614561844                1                0     NaN
# 2       1614588773                2               未知     1.0
# 3       1614599916                3                1     2.0
# 4       1614595418                3                1     3.0
#
#   takedlvr_aoi_type_name        dt
# 0                      0  20210301
# 1                     未知  20210301
# 2                      0  20210301
# 3                      0  20210301
# 4                      1  20210301

# %%
orders_train
# Out:
#          user_id  wm_order_id  wm_poi_id  aor_id order_price_interval  \
# 0         120037            0       1806       0                  <29
# 1         135109            1        970       6                 >=65
# 2         146736            2       1945       6              [29,36)
# 3          83644            3        708       6                 >=65
# 4         117903            4       2366       6              [29,36)
# ...          ...          ...        ...     ...                  ...
# 1068490    33987      1068490        378       4                 >=65
# 1068491    75439      1068491       2274       4                  <29
# 1068492    16555      1068492       1199       4                  <29
# 1068493   119357      1068493       2203       4              [29,36)
# 1068494   155481      1068494        423       4                 >=65
#
#          order_timestamp  ord_period_name order_scene_name  aoi_id  \
# 0             1614557985                0               未知     0.0
# 1             1614561844                1                0     NaN
# 2             1614588773                2               未知     1.0
# 3             1614599916                3                1     2.0
# 4             1614595418                3                1     3.0
# ...                  ...              ...              ...     ...
# 1068490       1616297056                1                1  2261.0
# 1068491       1616326217                3                7  1035.0
# 1068492       1616298147                1                1  2233.0
# 1068493       1616301559                1                1  2308.0
# 1068494       1616304519                1               未知  2245.0
#
#         takedlvr_aoi_type_name        dt
# 0                            0  20210301
# 1                           未知  20210301
# 2                            0  20210301
# 3                            0  20210301
# 4                            1  20210301
# ...                        ...       ...
# 1068490                      1  20210321
# 1068491                     11  20210321
# 1068492                      1  20210321
# 1068493                      1  20210321
# 1068494                      1  20210321
#
# [1068495 rows x 11 columns]

# %%
min(orders_train['dt'])
# Out:
# 20210301

# %%
path = './原数据-label-20210301-20210328/orders_poi_test_label.txt'
orders_test = pd.read_csv(path, sep = "\t")

# %%
orders_test.head()
# Out:
#    user_id  wm_order_id  wm_poi_id        dt
# 0   140760      1068495       2198  20210322
# 1    86307      1068496       3193  20210322
# 2   183993      1068497       1171  20210322
# 3   117653      1068498        629  20210322
# 4   120648      1068499       1719  20210322

# %%
# test if there is user never seen 
# result: no user never seen before
sum(pd.merge(orders_test, users, on = 'user_id', how='left')['avg_pay_amt'].isnull())
# Out:
# 0

# %%
# test if there is poi never seen 
# result: no poi never seen before
sum(pd.merge(orders_test, pois, on = 'wm_poi_id', how='left')['wm_poi_name'].isnull())
# Out:
# 0

# %%
len(orders_test['user_id'].unique())
# Out:
# 108739

# %% [markdown]
# ## 1.2 Cleaning Data

# %%
# pois

# %%
pois = pois[0:29070]

# %% [markdown]
# ## 1.3 Exploring

# %% [markdown]
# ### Most Bought POI

# %%
order_sort_by_poi = orders_train.groupby('wm_poi_id').count().sort_values('user_id',ascending = False)

# %%
order_sort_by_poi.head()
# Out:
#            user_id  wm_order_id  aor_id  order_price_interval  \
# wm_poi_id
# 1896          4535         4535    4535                  4535
# 244           4139         4139    4139                  4139
# 3230          4102         4102    4102                  4102
# 3193          3943         3943    3943                  3943
# 2933          3868         3868    3868                  3868
#
#            order_timestamp  ord_period_name  order_scene_name  aoi_id  \
# wm_poi_id
# 1896                  4535             4535              4535    4330
# 244                   4139             4139              4139    3531
# 3230                  4102             4102              4102    3766
# 3193                  3943             3943              3943    3647
# 2933                  3868             3868              3868    3737
#
#            takedlvr_aoi_type_name    dt
# wm_poi_id
# 1896                         4535  4535
# 244                          4139  4139
# 3230                         4102  4102
# 3193                         3943  3943
# 2933                         3868  3868

# %% [markdown]
# ## 1.4 Data preparing

# %%
# user without info
users_n_info = users['user_id'].to_frame()
# users_n_info = users_n_info [:10000]

# %%
users.head()
# Out:
#    user_id avg_pay_amt avg_pay_amt_weekdays avg_pay_amt_weekends
# 0        0     [36,49)              [29,36)              [36,49)
# 1        1     [49,65)              [49,65)                 >=65
# 2        2         <29                  <29                  <29
# 3        3     [49,65)                 >=65              [49,65)
# 4        4     [36,49)                   未知              [49,65)

# %%
user_index = {user: user for user in users['user_id']}

# %%
# order record
user_poi_buy = orders_train[['user_id','wm_poi_id']]
# user_poi_buy = user_poi_buy [:3000]

# %%
user_poi_buy['if_buy'] = 1
# Out:
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/1166971434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_poi_buy['if_buy'] = 1

# %%
pois['wm_poi_id'] = pois['wm_poi_id'].astype('int')

# %%
poi_index = {poi: poi for poi in pois['wm_poi_id']}

# %% [markdown]
# # 2 Recall Model

# %% [markdown]
# 2.1 Embedding: Get Candidate Set 1 by Embedding
#
# 2.2 Click History: Get Candidate Set 2 by extracting click history
#
# 2.3 Geo Relation: Get Candidate Set 3 by Frequent Geo Relation

# %% [markdown]
# ## 2.1 Embedding

# %% [markdown]
# **Embedding model needs a training set.** We are going to treat this as a supervised learning problem: given a pair (user, poi), we want the neural network to learn to predict whether this is a legitimate pair - present in the data - or not.

# %%
# positive links between users and pois

# %%
user_poi_buy.head()
# Out:
#    user_id  wm_poi_id  if_buy
# 0   120037       1806       1
# 1   135109        970       1
# 2   146736       1945       1
# 3    83644        708       1
# 4   117903       2366       1

# %%
pos_link_list = user_poi_buy[['user_id','wm_poi_id']].values.tolist()
pos_pairs = [tuple(link) for link in pos_link_list]
pos_pairs_set = set(pos_pairs)

# %%
len(pos_pairs_set)
# Out:
# 750529

# %%
len(pos_link_list)
# Out:
# 1068495

# %%
user_poi_num = user_poi_buy.groupby(['user_id','wm_poi_id'],as_index=False).sum('if_buy')
user_poi_num_list = user_poi_num[['user_id','wm_poi_id','if_buy']].values.tolist()

# %%
user_poi_num[user_poi_num['user_id'] == 1000]
# Out:
#       user_id  wm_poi_id  if_buy
# 3743     1000        198       1
# 3744     1000       1375       1

# %%
from collections import defaultdict
user_poi_num_dict = defaultdict(dict)
for i in user_poi_num_list:
    user_poi_num_dict[i[0]][i[1]] = i[2]

# %%
from collections import defaultdict
pos_pairs_dict = defaultdict(dict)
for k,v in pos_pairs_set:
    dict2 = {}
    dict2[v] = 1
    pos_pairs_dict[k][v] = 1

# %%
pos_pairs_dict[1]
# Out:
# {2044: 1, 1921: 1, 176: 1, 1725: 1, 2540: 1, 507: 1, 2043: 1, 43: 1}

# %%
user_poi_buy[user_poi_buy['user_id']==1]['wm_poi_id'].unique()
# Out:
# array([1725, 2540,  176, 1921,   43, 2044, 2043,  507], dtype=int64)

# %%
# negative links between users and pois

# %%
# user_poi_0

# %%
# neg_link_list = user_poi_0[['user_id','wm_poi_id']].values.tolist()
# neg_pairs = [tuple(link) for link in neg_link_list]
# neg_pairs_set = set(neg_pairs)

# %%
# len(neg_pairs_set)

# %% [markdown]
# To compute the embeddings, we are **not going to create a separate validation or testing set.** While this is a must for a normal supervised machine learning task, in this case, our primary objective is not to make the most accurate model, but to generate the best embeddings. The prediction task is just the method through which we train our network to make the embeddings. At the end of training, we are not going to be testing our model on new data, so we don't need to evaluate the performance.

# %% [markdown]
# The code below creates **a generator that yields batches of samples each time it is called**. Neural networks are trained incrementally - a batch at a time - which means that a generator is a useful function for returning examples on which to train.

# %%
import random
random.seed(100)
def generate_batch(pairs, n_positive = 50, negative_ratio = 1.0, classification = True):
    """Generate batches of samples for training"""
    batch_size = n_positive * (1 + negative_ratio)
    batch = np.zeros((batch_size, 3))
    
    # Adjust label based on task
    if classification:
        neg_label = 0
    else:
        neg_label = -1
    
    # This creates a generator
    while True:
        # randomly choose positive examples
        for idx, (user_id, wm_poi_id) in enumerate(random.sample(pairs, n_positive)):
            batch[idx, :] = (user_id, wm_poi_id, 1)

        # Increment idx by 1
        idx += 1
        
        # Add negative examples until reach batch size
        while idx < batch_size:
            
            # random selection
            random_user = random.randrange(len(users))
            random_poi = random.randrange(len(pois))
            
            # Check to make sure this is not a positive example
            if (random_user, random_poi) not in pos_pairs_set:
                
                # Add to batch and increment index
                batch[idx, :] = (random_user, random_poi, neg_label)
                idx += 1
                
        # Make sure to shuffle order
        np.random.shuffle(batch)
        yield {'user': batch[:, 0], 'poi': batch[:, 1]}, batch[:, 2]

# %%
next(generate_batch(pos_pairs, n_positive = 2, negative_ratio = 3))
# Out:
# ({'user': array([ 45809.,  91681., 132871., 119256., 177770., 103031.,  28827.,
#          120751.]),
#   'poi': array([23118., 14205., 26215., 25257.,  2897., 23984., 17462.,    48.])},
#  array([0., 0., 0., 0., 1., 0., 0., 1.]))

# %% [markdown]
# **Neural Network Embedding Model**

# %%
# pip install keras

# %%
# pip install tensorflow

# %%
import keras
from keras.layers import Input, Embedding, Dot, Reshape, Dense
from keras.models import Model

# %%
def user_embedding_model(embedding_size = 50, classification = False):
    """Model to embed users and pois using the functional API.
       Trained to discern if a link is present in the user poi pairs (which is orders)"""
    
    # Both inputs are 1-dimensional
    user = Input(name = 'user', shape = [1])
    poi = Input(name = 'poi', shape = [1])
    
    # Embedding the user (shape will be (None, 1, 50))
    user_embedding = Embedding(name = 'user_embedding',
                               input_dim = len(users['user_id']),
                               output_dim = embedding_size)(user)
    
    # Embedding the poi (shape will be (None, 1, 50))
    poi_embedding = Embedding(name = 'poi_embedding',
                               input_dim = len(pois['wm_poi_id']),
                               output_dim = embedding_size)(poi)
    
    # Merge the layers with a dot product along the second axis (shape will be (None, 1, 1))
    merged = Dot(name = 'dot_product', normalize = True, axes = 2)([user_embedding, poi_embedding])
    
    # Reshape to be a single number (shape will be (None, 1))
    merged = Reshape(target_shape = [1])(merged)
    
    # If classifcation, add extra layer and loss function is binary cross entropy
    if classification:
        merged = Dense(1, activation = 'sigmoid')(merged)
        model = Model(inputs = [user, poi], outputs = merged)
        model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    # Otherwise loss function is mean squared error
    else:
        model = Model(inputs = [user, poi], outputs = merged)
        model.compile(optimizer = 'Adam', loss = 'mse')
    
    return model

# Instantiate model and show parameters
model = user_embedding_model()
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  user (InputLayer)              [(None, 1)]          0           []
#
#  poi (InputLayer)               [(None, 1)]          0           []
#
#  user_embedding (Embedding)     (None, 1, 50)        10000000    ['user[0][0]']
#
#  poi_embedding (Embedding)      (None, 1, 50)        1453500     ['poi[0][0]']
#
#  dot_product (Dot)              (None, 1, 1)         0           ['user_embedding[0][0]',
#                                                                   'poi_embedding[0][0]']
#
#  reshape_3 (Reshape)            (None, 1)            0           ['dot_product[0][0]']
#
# ==================================================================================================
# Total params: 11,453,500
# Trainable params: 11,453,500
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Train Embedding Model**

# %%
n_positive = 1024

gen = generate_batch(pos_pairs, n_positive, negative_ratio = 2)

# Train
h = model.fit(x = gen, epochs = 15,steps_per_epoch = len(pos_pairs) // n_positive,verbose = 2)
# Out:
# Epoch 1/15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/4010965672.py in <module>
#       4
#       5 # Train
# ----> 6 h = model.fit(x = gen, epochs = 15,steps_per_epoch = len(pos_pairs) // n_positive,verbose = 2)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1218                 context.async_wait()
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
# -> 1220               end_step = step + data_handler.step_increment
#    1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in step_increment(self)
#    1268         self._steps_per_execution.assign(original_spe)
#    1269
# -> 1270   @property
#    1271   def step_increment(self):
#    1272     """The number to increment the step for `on_batch_end` methods."""
#
# KeyboardInterrupt:

# %%
model.save('./models/first_attempt.h5')

# %%
model = keras.models.load_model('./models/first_attempt.h5')

# %% [markdown]
# **Extract Embeddings and Analyze**

# %%
# Extract embeddings
user_layer = model.get_layer('user_embedding')
user_weights = user_layer.get_weights()[0]
user_weights.shape
# Out:
# (200000, 50)

# %% [markdown]
# Each user is now represented as a 50-dimensional vector.
#
# We need to normalize the embeddings so that the dot product between two embeddings becomes the cosine similarity.

# %%
user_weights = user_weights / np.linalg.norm(user_weights, axis = 1).reshape((-1, 1))
user_weights[0][:10]
np.sum(np.square(user_weights[0]))
# Out:
# 1.0

# %% [markdown]
# Normalize just means divide each vector by the square root of the sum of squared components.

# %% [markdown]
# **Finding Similar users**

# %% [markdown]
# Function to Find Most Similar Entities

# %% [markdown]
# The function below takes in either a user or a poi, a set of embeddings, and returns the n most similar items to the query. It does this by computing the dot product between the query and embeddings. Because we normalized the embeddings, the dot product represents the cosine similarity between two vectors. This is a measure of similarity that does not depend on the magnitude of the vector in contrast to the Euclidean distance.
#
# Once we have the dot products, we can sort the results to find the closest entities in the embedding space. With cosine similarity, higher numbers indicate entities that are closer together, with -1 the furthest apart and +1 closest together.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['font.size'] = 15

def find_similar(name, weights, index_name = 'user', n = 10, least = False, return_dist = False, plot = False):
    """Find n most similar items (or least) to name based on embeddings. Option to also plot the results"""
    
    # Select index and reverse index
    if index_name == 'user':
        index = user_index
    elif index_name == 'poi':
        index = poi_index
    
    # Check to make sure `name` is in index
    try:
        # Calculate dot product between book and all others
        dists = np.dot(weights, weights[index[name]])
    except KeyError:
        print(f'{name} Not Found.')
        return
    
    # Sort distance indexes from smallest to largest
    sorted_dists = np.argsort(dists)
    
    # Plot results if specified
    if plot:
        
        # Find furthest and closest items
        furthest = sorted_dists[:(n // 2)]
        closest = sorted_dists[-n-1: len(dists) - 1]
        items = [index[c] for c in furthest]
        items.extend(index[c] for c in closest)
        
        # Find furthest and closets distances
        distances = [dists[c] for c in furthest]
        distances.extend(dists[c] for c in closest)
        
        colors = ['r' for _ in range(n //2)]
        colors.extend('g' for _ in range(n))
        
        data = pd.DataFrame({'distance': distances}, index = items)
        
        # Horizontal bar chart
        data['distance'].plot.barh(color = colors, figsize = (10, 8),
                                   edgecolor = 'k', linewidth = 2)
        plt.xlabel('Cosine Similarity');
        plt.axvline(x = 0, color = 'k');
        
        # Formatting for italicized title
        name_str = f'{index_name.capitalize()}s Most and Least Similar to'
        for word in str(name).split():
            # Title uses latex for italize
            name_str += ' $\it{' + word + '}$'
        plt.title(name_str, x = 0.2, size = 28, y = 1.05)
        
        return None
    
    # If specified, find the least similar
    if least:
        # Take the first n from sorted distances
        closest = sorted_dists[:n]
         
        print(f'{index_name.capitalize()}s furthest from {name}.\n')
        
    # Otherwise find the most similar
    else:
        # Take the last n sorted distances
        closest = sorted_dists[-n:]
        
        # Need distances later on
        if return_dist:
            return dists, closest
        
        
        print(f'{index_name.capitalize()}s closest to {name}.\n')
        
    # Need distances later on
    if return_dist:
        return dists, closest
    
    
    # Print formatting
    max_width = 6
    
    # Print the most similar and distances
    for c in reversed(closest):
        print(f'{index_name.capitalize()}: {index[c]:{max_width + 2}} Similarity: {dists[c]:.{2}}')

# %%
find_similar(20000, user_weights, index_name='user', n = 10, least = False)
# Out:
# Users closest to 20000.
#
# User:    20000 Similarity: 1.0
# User:    92908 Similarity: 0.98
# User:    11497 Similarity: 0.98
# User:   154020 Similarity: 0.98
# User:   110904 Similarity: 0.98
# User:   115241 Similarity: 0.98
# User:   153573 Similarity: 0.98
# User:   183310 Similarity: 0.98
# User:   106814 Similarity: 0.98
# User:    71779 Similarity: 0.98

# %% [markdown]
# **Finding Similar pois**

# %%
def extract_weights(name, model):
    """Extract weights from a neural network model"""
    
    # Extract weights
    weight_layer = model.get_layer(name)
    weights = weight_layer.get_weights()[0]
    
    # Normalize
    weights = weights / np.linalg.norm(weights, axis = 1).reshape((-1, 1))
    return weights

# %%
poi_weights = extract_weights('poi_embedding', model)

# %%
find_similar(20000, poi_weights, index_name='poi', n = 10, least = False)
# Out:
# Pois closest to 20000.
#
# Poi:    20000 Similarity: 1.0
# Poi:     7804 Similarity: 0.6
# Poi:    28373 Similarity: 0.59
# Poi:    13880 Similarity: 0.58
# Poi:    19624 Similarity: 0.57
# Poi:     7850 Similarity: 0.55
# Poi:    21925 Similarity: 0.55
# Poi:    12570 Similarity: 0.55
# Poi:    21639 Similarity: 0.54
# Poi:    26934 Similarity: 0.53

# %%
find_similar(20000, poi_weights, index_name='poi', n=5, plot=True)

# %% [markdown]
# ## Classification Model

# %% [markdown]
# For this model, the negative examples receive a label of 0 and the loss function is binary cross entropy. The procedure for the neural network to learn the embeddings is exactly the same, only it will be optimizing for a slightly different measure.

# %%
model_class = user_embedding_model(50, classification = True)
n_positive = 1024
gen = generate_batch(pos_pairs_set, n_positive, negative_ratio=2, classification = True)

# %%
# Train the model to learn embeddings
h = model_class.fit_generator(gen, epochs = 15, steps_per_epoch= len(pos_pairs_set) // n_positive, verbose = 0)

# %%
model_class.save('./models/first_attempt_class.h5')

# %%
model_class = keras.models.load_model('./models/first_attempt_class.h5')

# %%
user_weights_class = extract_weights('user_embedding', model_class)
user_weights_class.shape
# Out:
# (200000, 50)

# %%
find_similar(20000, user_weights_class, n = 5)
# Out:
# Users closest to 20000.
#
# User:    20000 Similarity: 1.0
# User:   132961 Similarity: 0.58
# User:   187258 Similarity: 0.56
# User:   110573 Similarity: 0.55
# User:   118207 Similarity: 0.53

# %% [markdown]
# Things are looking pretty good with this model as well.

# %%
poi_weights_class = extract_weights('poi_embedding', model_class)

# %%
find_similar(20000, poi_weights_class, index_name = 'poi', n = 5)
# Out:
# Pois closest to 20000.
#
# Poi:    20000 Similarity: 1.0
# Poi:    11539 Similarity: 0.59
# Poi:    18938 Similarity: 0.57
# Poi:     4244 Similarity: 0.52
# Poi:      484 Similarity: 0.49

# %% [markdown]
# Ouput poi weight and user weight:

# %%
poi_weight_df = pd.DataFrame()
poi_weight_df['wm_poi_id'] = range(len(poi_weights_class))

# %%
poi_weight_df = pd.merge(poi_weight_df, pd.DataFrame(poi_weights_class),left_index=True, right_index=True)

# %%
poi_weight_df
# Out:
#        wm_poi_id         0         1         2         3         4         5  \
# 0              0  0.132705  0.175800 -0.172187  0.119012  0.086187  0.132620
# 1              1 -0.033424 -0.219331 -0.103522 -0.032392 -0.218288 -0.027776
# 2              2  0.172315  0.120970  0.068058  0.150311 -0.075045  0.240324
# 3              3  0.032110 -0.128632 -0.176455  0.246872 -0.031325 -0.082448
# 4              4  0.106671  0.144365  0.053859  0.127882  0.011445 -0.223120
# ...          ...       ...       ...       ...       ...       ...       ...
# 29065      29065 -0.202894 -0.193259  0.057906  0.093414  0.129429 -0.188316
# 29066      29066  0.035572 -0.227226 -0.256053 -0.230141 -0.155398 -0.017856
# 29067      29067 -0.187436 -0.095532 -0.185322 -0.154379  0.024887  0.178086
# 29068      29068 -0.075566  0.109128  0.034748  0.101993 -0.198499 -0.134956
# 29069      29069 -0.167994 -0.091158 -0.047080  0.240742  0.136857 -0.066467
#
#               6         7         8  ...        40        41        42  \
# 0      0.207318 -0.204776  0.100612  ... -0.105960  0.063412  0.151492
# 1     -0.083874  0.181628 -0.060951  ... -0.125921  0.054128  0.169274
# 2      0.191489 -0.187889 -0.221711  ...  0.230301 -0.092832 -0.102575
# 3     -0.108321  0.183504  0.172803  ...  0.003501  0.004790  0.011174
# 4     -0.070605  0.146527  0.193761  ... -0.087836  0.129123 -0.206227
# ...         ...       ...       ...  ...       ...       ...       ...
# 29065 -0.217280 -0.039571  0.100439  ...  0.068266  0.140629  0.206565
# 29066  0.093773 -0.182920  0.246493  ... -0.128433  0.114975 -0.115288
# 29067  0.026928  0.047917 -0.108013  ... -0.086655 -0.003600 -0.055387
# 29068  0.018299 -0.221570 -0.176926  ... -0.028132 -0.059061  0.227162
# 29069 -0.195733 -0.195240  0.198789  ... -0.099095  0.009742  0.007852
#
#              43        44        45        46        47        48        49
# 0      0.156352  0.191741  0.020405 -0.138973  0.109481  0.133383  0.202510
# 1     -0.111439  0.092693  0.124213 -0.029066  0.218887  0.098789 -0.200461
# 2     -0.061537  0.143014 -0.119426 -0.145911 -0.206351 -0.231030  0.077795
# 3     -0.093093 -0.126317  0.095541 -0.074738  0.188373 -0.189244 -0.033693
# 4     -0.233125 -0.131641 -0.106418  0.158003  0.021087 -0.228226  0.176679
# ...         ...       ...       ...       ...       ...       ...       ...
# 29065  0.182867  0.112989 -0.177265  0.015165 -0.074535 -0.141443 -0.031254
# 29066  0.036912 -0.196873  0.076226  0.097127 -0.137136  0.149444  0.100536
# 29067  0.152793  0.039193 -0.131682 -0.173959  0.230021  0.068750 -0.220196
# 29068  0.147055 -0.166883  0.107847 -0.185667 -0.171083  0.133735  0.050819
# 29069 -0.083016  0.174262 -0.208967  0.078730 -0.054828 -0.005800 -0.115746
#
# [29070 rows x 51 columns]

# %%
user_weight_df = pd.DataFrame()
user_weight_df['user_id'] = range(len(user_weights_class))

# %%
user_weight_df = pd.merge(user_weight_df, pd.DataFrame(user_weights_class),left_index=True, right_index=True)

# %%
user_weight_df
# Out:
#         user_id         0         1         2         3         4         5  \
# 0             0  0.172294  0.076123  0.222883 -0.112934  0.122184 -0.095396
# 1             1 -0.057762 -0.112400  0.187527  0.007343  0.207096  0.028353
# 2             2  0.073514  0.039960  0.171098  0.159742  0.234158  0.189388
# 3             3 -0.165159 -0.222396  0.153270  0.136046  0.112825 -0.088027
# 4             4 -0.183768  0.069068 -0.119061  0.050102  0.227482  0.074328
# ...         ...       ...       ...       ...       ...       ...       ...
# 199995   199995 -0.053740  0.151810  0.033439  0.220974 -0.166832 -0.154977
# 199996   199996  0.161498 -0.119906  0.109334  0.041855  0.169338 -0.204994
# 199997   199997  0.211052  0.202270  0.134006  0.044839 -0.204592 -0.063615
# 199998   199998  0.062807  0.064156 -0.132265  0.076176 -0.209961  0.089272
# 199999   199999 -0.022685  0.134971  0.104754 -0.007993 -0.230644  0.109969
#
#                6         7         8  ...        40        41        42  \
# 0       0.077262 -0.074048 -0.217209  ...  0.154340  0.182537  0.155856
# 1       0.070175  0.201103 -0.007949  ... -0.138624 -0.013349 -0.129199
# 2      -0.045357 -0.026566  0.013764  ...  0.168431 -0.152057  0.066710
# 3      -0.216146  0.199616  0.098019  ... -0.111946  0.040729 -0.082420
# 4       0.008011 -0.160015 -0.212736  ... -0.000693 -0.133425  0.132013
# ...          ...       ...       ...  ...       ...       ...       ...
# 199995 -0.188797 -0.109301 -0.080695  ...  0.142148  0.021109 -0.040488
# 199996 -0.041900  0.030022  0.059638  ...  0.114324 -0.185847  0.231849
# 199997  0.228813 -0.092693 -0.030198  ...  0.155127  0.188050 -0.202825
# 199998 -0.170242  0.052951 -0.189638  ... -0.228556 -0.138433  0.224445
# 199999  0.077321  0.098141  0.216623  ... -0.219118 -0.002943 -0.160328
#
#               43        44        45        46        47        48        49
# 0       0.228492  0.006066  0.010654  0.195371  0.127906  0.199655  0.141253
# 1      -0.172272 -0.095102  0.214184 -0.228044 -0.025532 -0.162152 -0.062634
# 2      -0.218484 -0.159288 -0.033473  0.088738 -0.026042 -0.173756 -0.105594
# 3       0.074480  0.215741 -0.201678  0.002880  0.148105 -0.221117 -0.147675
# 4      -0.202879 -0.019098 -0.218935 -0.171182  0.166010  0.213556 -0.063843
# ...          ...       ...       ...       ...       ...       ...       ...
# 199995 -0.032924  0.222740  0.142006 -0.062243  0.073249  0.108478  0.016090
# 199996 -0.164378  0.062731  0.110636  0.117247  0.043663  0.246945 -0.180847
# 199997  0.232739  0.105010  0.159728  0.148523 -0.140499 -0.074509  0.108539
# 199998 -0.202977 -0.188526 -0.089289  0.030354 -0.191165  0.043319  0.211236
# 199999  0.082996  0.113453  0.106510 -0.058910  0.198101 -0.111561 -0.206852
#
# [200000 rows x 51 columns]

# %%
poi_weight_df.to_csv("dat/poi_weight.csv", index=False)
user_weight_df.to_csv("dat/user_weight.csv", index=False)

# %% [markdown]
# ## U2I (U2POI)

# %%
def poi_recommend_4_user(user, user_weights, n_sim_user, n_top_poi):
    # user: the user to get recommend poi
    # user_weights: embedded user weight, this is to calculate user similarity
    # n_sim_user
    # n_top_poi: Top n pois to return
    # Gets recommendations for a person by using a weighted average of every other user's rankings
    
    # Tried for sevearal a times, for a curve and it turns out that bought pois of the most similar xxx users' perform well
    
    totals = {}
    sim_sum = {}
    
    rankings_list =[]
    
    dists = np.dot(user_weights, user_weights[user_index[user]])
    sim_user_index = dists.argsort()[::-1][0:n_sim_user] 
    
    for other_user in sim_user_index:
        user_sim = dists[other_user]
        pois_bought = user_poi_num_dict[other_user].keys()
        pois_bought_tt = sum(user_poi_num_dict[other_user].values())
        
        for poi in pois_bought:
            # Similrity * score
            totals.setdefault(poi,0)
             # make sure to extract 0 though there is no this value
            user_poi_num_dict[other_user].setdefault(poi,0)
            totals[poi] += user_poi_num_dict[other_user][poi] * user_sim
            # print(totals[poi])
            
            # sum of similarities
            sim_sum.setdefault(poi,0)
            sim_sum[poi]+= user_sim
            # print(sim_sum[poi])
        
        # print('loop done for other user:')
        # print(other_user)
    
    rankings = [(total/sim_sum[poi],poi) for poi,total in totals.items()]
    rankings.sort()
    rankings.reverse()
    recommend_list = [recommend_item for score,recommend_item in rankings]
    return recommend_list[0:n]

# %%
import random
random.seed(20211221)
sample_users = random.sample(user_index.keys(), 1000)

# %%
# pip install line_profiler

# %%
sim_user_eval = {}

for sim_user in np.arange(0,500,50):
    top_poi_4_user_dict = defaultdict(list)
    for user in sample_users:
        top_poi_4_user_dict[user] = poi_recommend_4_user(user,user_weights_class,sim_user, 500)
    
    # Check Hit Radio Performance
    test_pairs_pos = orders_test.values.tolist()
    poi_hit = 0
    poi_num = 0
    for test_pair_index in sample_users:
        pos_pois = pos_pairs_dict_test[test_pair_index].keys()

        for poi in pos_pois:
            poi_num += 1
            if poi in top_poi_4_user_dict[test_pair_index]:
                poi_hit += 1

    hit_ratio = poi_hit/poi_num
    
    sim_user_eval[sim_user] = hit_ratio
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/1525374076.py in <module>
#       4     top_poi_4_user_dict = defaultdict(list)
#       5     for user in sample_users:
# ----> 6         top_poi_4_user_dict[user] = poi_recommend_4_user(user,user_weights_class,sim_user, 500)
#       7
#       8     # Check Hit Radio Performance
#
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/1486165421.py in poi_recommend_4_user(user, user_weights, n_sim_user, n_top_poi)
#      13     rankings_list =[]
#      14
# ---> 15     dists = np.dot(user_weights, user_weights[user_index[user]])
#      16     sim_user_index = dists.argsort()[::-1][0:n_sim_user]
#      17
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
sim_user_eval
# Out:
# {0: 0.0,
#  50: 0.23541453428863868,
#  100: 0.16069600818833163,
#  150: 0.13510747185261002,
#  200: 0.1187308085977482,
#  250: 0.10030706243602866,
#  300: 0.09621289662231321,
#  350: 0.08085977482088025,
#  400: 0.07574206755373593}

# %%
# test to recommend to user
from collections import defaultdict

top_poi_4_user_dict = defaultdict(list)
for user in user_sampled_list:
    top_poi_4_user_dict[user] = poi_recommend_4_user(user,user_weights_class,500)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/3340668261.py in <module>
#       4 top_poi_4_user_dict = defaultdict(list)
#       5 for user in user_sampled_list:
# ----> 6     top_poi_4_user_dict[user] = poi_recommend_4_user(user,user_weights_class,500)
#
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/2406781499.py in poi_recommend_4_user(user, user_weights, n)
#      12     rankings_list =[]
#      13
# ---> 14     dists = np.dot(user_weights, user_weights[user_index[user]])
#      15     sim_user_index = dists.argsort()[::-1][0:200]
#      16
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
from collections import defaultdict

top_poi_4_user_dict = defaultdict(list)
for user in user_index:
    top_poi_4_user_dict[user] = poi_recommend_4_user(user,user_weights_class,500)

# %%
# top_poi_4_user_dict

# %%
orders_test.head()
# Out:
#    user_id  wm_order_id  wm_poi_id        dt
# 0   140760      1068495       2198  20210322
# 1    86307      1068496       3193  20210322
# 2   183993      1068497       1171  20210322
# 3   117653      1068498        629  20210322
# 4   120648      1068499       1719  20210322

# %%
pos_pairs_list_test = orders_test[['user_id','wm_poi_id']].values.tolist()
pos_pairs_test = [tuple(link) for link in pos_pairs_list_test]
pos_pairs_set_test = set(pos_pairs_test)
pos_pairs_dict_test = defaultdict(dict)
for k,v in pos_pairs_set_test:
    dict2 = {}
    dict2[v] = 1
    pos_pairs_dict_test[k][v] = 1

# %%
# Check Hit Radio Performance

test_pairs_pos = orders_test.values.tolist()

poi_hit = 0
poi_num = 0

for test_pair_index in user_sampled_list:
    pos_pois = pos_pairs_dict_test[test_pair_index].keys()
    
    for poi_index in pos_pois:
        poi_num += 1
        if poi_index in top_poi_4_user_dict[test_pair_index]:
            poi_hit += 1

hit_ratio = poi_hit/poi_num

# %%
hit_ratio
# Out:
# 0.5341745531019979

# %% [markdown]
# ## OUTPUT

# %%
# output overall result
top_poi_4_user_values = []
for user in top_poi_4_user_dict:
    for rcmd in top_poi_4_user_dict[user]:
        top_poi_4_user_values.append([user,rcmd])

top_poi_4_user_df = pd.DataFrame(top_poi_4_user_values)

# %%
# Sampling user result
path = './dat/order_train_sampling.csv'
user_sampled_list = pd.read_csv(path)['user_id'].unique()

# %%
user_sampled_list
# Out:
# array([ 29722, 188974,  63155, ...,  99568,  88804, 118954], dtype=int64)

# %%
# ouput sampling result
top_poi_4_user_values = []
for user in top_poi_4_user_dict:
    # output sample result
    if user in user_sampled_list:
        for rcmd in top_poi_4_user_dict[user]:
            top_poi_4_user_values.append([user,rcmd])
    else:
        continue

top_poi_4_user_sampled_df = pd.DataFrame(top_poi_4_user_values)
top_poi_4_user_sampled_df.rename(columns={0:'user_id',1:'wm_poi_id'},inplace=True)

# %%
top_poi_4_user_sampled_df.to_csv("dat/top_poi_4_user_sampled.csv", index=False)

# %%
top_poi_4_user_sampled_df.head()
# Out:
#    user_id  wm_poi_id
# 0        4       3295
# 1        4       3305
# 2        4       2670
# 3        4        546
# 4        4       2726

# %% [markdown]
# ## 2.2 Click Hsitory

# %%
path = './原数据-20210301-20210328/orders_poi_session.txt'
click_his = pd.read_csv(path, sep = "\t")

# %%
user_click_raw = pd.merge(orders_train, click_his, on='wm_order_id')[['user_id', 'clicks']]
user_click_raw
# Out:
#          user_id                                             clicks
# 0         120037  174#2975#28046#1370#1030#469#18954#9862#25385#...
# 1         135109    18915#18915#18915#18915#18915#18915#18915#18915
# 2         146736  303#1854#1482#1108#1487#1945#13715#1945#13715#...
# 3          83644                                                NaN
# 4         117903                                                NaN
# ...          ...                                                ...
# 1068490    33987                                                NaN
# 1068491    75439                                                NaN
# 1068492    16555  2369#2061#2061#1030#1030#2711#11155#27933#1339...
# 1068493   119357   516#2725#2725#2681#1170#1170#149#149#149#149#212
# 1068494   155481                             22893#12427#12427#2369
#
# [1068495 rows x 2 columns]

# %%
user_click_df = user_click_raw.drop('clicks', axis=1).join(user_click_raw['clicks'].str.split('#', expand=True).stack().reset_index(level=1, drop=True).rename('click'))

# %%
user_click_list = user_click_df.values.tolist()

# %%
user_click_list
# Out:
# [[120037, '174'],
#  [120037, '2975'],
#  [120037, '28046'],
#  [120037, '1370'],
#  [120037, '1030'],
#  [120037, '469'],
#  [120037, '18954'],
#  [120037, '9862'],
#  [120037, '25385'],
#  [120037, '2885'],
#  [120037, '9862'],
#  [120037, '9862'],
#  [120037, '9862'],
#  [120037, '9862'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [135109, '18915'],
#  [146736, '303'],
#  [146736, '1854'],
#  [146736, '1482'],
#  [146736, '1108'],
#  [146736, '1487'],
#  [146736, '1945'],
#  [146736, '13715'],
#  [146736, '1945'],
#  [146736, '13715'],
#  [146736, '13715'],
#  [146736, '13715'],
#  [146736, '13715'],
#  [83644, nan],
#  [117903, nan],
#  [64640, '935'],
#  [64640, '1797'],
#  [64640, '1954'],
#  [64640, '1954'],
#  [64640, '1797'],
#  [29722, '2066'],
#  [29722, '181'],
#  [29722, '181'],
#  [29722, '182'],
#  [64513, '525'],
#  [64513, '525'],
#  [64513, '3076'],
#  [64513, '419'],
#  [64513, '1837'],
#  [64513, '3008'],
#  [64513, '1518'],
#  [64513, '419'],
#  [109205, nan],
#  [161617, nan],
#  [188974, '2775'],
#  [188974, '2775'],
#  [188974, '212'],
#  [8178, nan],
#  [132875, '3041'],
#  [132875, '3041'],
#  [132875, '3041'],
#  [134010, nan],
#  [27174, nan],
#  [168056, '114'],
#  [168056, '2936'],
#  [155313, nan],
#  [174, nan],
#  [138918, nan],
#  [179790, nan],
#  [158888, '22036'],
#  [158888, '2720'],
#  [158888, '22036'],
#  [158888, '22036'],
#  [158888, '22036'],
#  [158888, '2720'],
#  [158888, '528'],
#  [158888, '2720'],
#  [158888, '1071'],
#  [158888, '2214'],
#  [158888, '2720'],
#  [158888, '2720'],
#  [158888, '2720'],
#  [158888, '2720'],
#  [158888, '3222'],
#  [158888, '175'],
#  [158888, '22036'],
#  [158888, '215'],
#  [158888, '1195'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '2861'],
#  [158888, '2182'],
#  [158888, '175'],
#  [158888, '22815'],
#  [158888, '205'],
#  [158888, '916'],
#  [158888, '205'],
#  [158888, '3031'],
#  [158888, '3490'],
#  [158888, '1827'],
#  [158888, '806'],
#  [158888, '1030'],
#  [158888, '1030'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '2610'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '6584'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [158888, '916'],
#  [160763, '2134'],
#  [160763, '2977'],
#  [160763, '1589'],
#  [160763, '1962'],
#  [160763, '1335'],
#  [160763, '3270'],
#  [160763, '2119'],
#  [160763, '2119'],
#  [160763, '2119'],
#  [160763, '2119'],
#  [160763, '273'],
#  [5661, '1805'],
#  [5661, '2050'],
#  [37672, nan],
#  [144393, nan],
#  [63155, '2137'],
#  [63155, '2137'],
#  [63155, '1807'],
#  [63155, '1237'],
#  [63155, '2347'],
#  [63155, '12413'],
#  [63155, '2588'],
#  [63155, '2137'],
#  [63155, '2137'],
#  [63155, '2137'],
#  [63155, '2137'],
#  [36555, nan],
#  [187824, '1311'],
#  [187824, '2257'],
#  [187824, '2257'],
#  [187824, '2257'],
#  [187824, '2257'],
#  [187824, '2140'],
#  [187824, '1966'],
#  [187824, '11394'],
#  [187824, '566'],
#  [187824, '2498'],
#  [187824, '1798'],
#  [187824, '2588'],
#  [187824, '2140'],
#  [187824, '3228'],
#  [187824, '3228'],
#  [187824, '2257'],
#  [187824, '2257'],
#  [187824, '2257'],
#  [186409, nan],
#  [35957, '757'],
#  [35957, '534'],
#  [35957, '3118'],
#  [35957, '3118'],
#  [35957, '3118'],
#  [35957, '3118'],
#  [2311, '3132'],
#  [2311, '1557'],
#  [2311, '763'],
#  [2311, '976'],
#  [2311, '60'],
#  [2311, '2535'],
#  [2311, '3285'],
#  [121834, nan],
#  [50872, '414'],
#  [50872, '534'],
#  [50872, '534'],
#  [50872, '534'],
#  [50872, '534'],
#  [158615, nan],
#  [110414, nan],
#  [141741, '1127'],
#  [141741, '1127'],
#  [141741, '1127'],
#  [141741, '1127'],
#  [141741, '1218'],
#  [96097, '1886'],
#  [96097, '311'],
#  [96097, '1169'],
#  [96097, '3005'],
#  [96097, '516'],
#  [96097, '201'],
#  [96097, '2912'],
#  [96097, '2224'],
#  [96097, '2224'],
#  [96097, '1074'],
#  [96097, '1181'],
#  [46240, nan],
#  [112737, '2019'],
#  [112737, '2996'],
#  [112737, '1372'],
#  [112737, '1372'],
#  [112737, '2085'],
#  [112737, '1426'],
#  [112737, '1373'],
#  [112737, '1373'],
#  [112737, '1372'],
#  [112737, '833'],
#  [112737, '1411'],
#  [112737, '1411'],
#  [112737, '2930'],
#  [112737, '114'],
#  [112737, '833'],
#  [38247, nan],
#  [103212, nan],
#  [197267, nan],
#  [59091, '2841'],
#  [59091, '11124'],
#  [59091, '2841'],
#  [59091, '2284'],
#  [130491, nan],
#  [100912, nan],
#  [24328, nan],
#  [16124, nan],
#  [29436, '113'],
#  [29436, '184'],
#  [29436, '1126'],
#  [29436, '920'],
#  [29436, '2092'],
#  [29436, '4755'],
#  [29436, '184'],
#  [178805, nan],
#  [33810, nan],
#  [57001, '1522'],
#  [57001, '1522'],
#  [57001, '414'],
#  [57001, '414'],
#  [57001, '6064'],
#  [57001, '2888'],
#  [57001, '2070'],
#  [57001, '2033'],
#  [57001, '21626'],
#  [57001, '290'],
#  [57001, '1668'],
#  [57001, '485'],
#  [57001, '2344'],
#  [57001, '2761'],
#  [57001, '2070'],
#  [57001, '725'],
#  [57001, '1272'],
#  [57001, '1272'],
#  [57001, '1384'],
#  [57001, '1482'],
#  [57001, '3073'],
#  [57001, '3073'],
#  [57001, '3073'],
#  [57001, '6064'],
#  [57001, '1434'],
#  [57001, '1434'],
#  [57001, '1753'],
#  [57001, '4808'],
#  [57001, '27890'],
#  [57001, '1384'],
#  [57001, '1384'],
#  [57001, '633'],
#  [120658, nan],
#  [176056, '1551'],
#  [176056, '18854'],
#  [176056, '18854'],
#  [16797, nan],
#  [923, '2996'],
#  [923, '13750'],
#  [124725, nan],
#  [23739, '15040'],
#  [23739, '2428'],
#  [93699, '2428'],
#  [93699, '1263'],
#  [72096, '303'],
#  [72096, '303'],
#  [38328, nan],
#  [46271, '2403'],
#  [46271, '1768'],
#  [174334, '20208'],
#  [174334, '20206'],
#  [174334, '12408'],
#  [174334, '18865'],
#  [174334, '20208'],
#  [174334, '633'],
#  [174334, '894'],
#  [174334, '20208'],
#  [174334, '1670'],
#  [174334, '2498'],
#  [174334, '9916'],
#  [174334, '1670'],
#  [174334, '1670'],
#  [174334, '1122'],
#  [174334, '3207'],
#  [174334, '25'],
#  [174334, '12408'],
#  [174334, '20206'],
#  [174334, '20208'],
#  [174334, '17628'],
#  [174334, '16357'],
#  [174334, '16357'],
#  [87619, '704'],
#  [149001, nan],
#  [133378, '17653'],
#  [133378, '2092'],
#  [133378, '2334'],
#  [133378, '523'],
#  [133378, '2207'],
#  [133378, '3131'],
#  [133378, '2535'],
#  [133378, '22848'],
#  [96073, nan],
#  [186056, '1925'],
#  [186056, '376'],
#  [186056, '3131'],
#  [186056, '376'],
#  [186056, '376'],
#  [186056, '1667'],
#  [186056, '633'],
#  [186056, '149'],
#  [26347, '2011'],
#  [26347, '2977'],
#  [26347, '1136'],
#  [26347, '1644'],
#  [26347, '830'],
#  [26347, '852'],
#  [26347, '2517'],
#  [26347, '2517'],
#  [26347, '2016'],
#  [26347, '3222'],
#  [26347, '2016'],
#  [150459, '2964'],
#  [96097, '1886'],
#  [96097, '311'],
#  [96097, '1169'],
#  [96097, '3005'],
#  [96097, '516'],
#  [96097, '201'],
#  [96097, '2912'],
#  [96097, '2224'],
#  [96097, '2224'],
#  [96097, '1074'],
#  [96097, '1181'],
#  [115837, '975'],
#  [115837, '975'],
#  [115837, '975'],
#  [115837, '975'],
#  [115837, '2162'],
#  [21654, nan],
#  [47244, '3054'],
#  [47244, '2485'],
#  [159800, '2202'],
#  [159800, '2061'],
#  [159800, '2202'],
#  [159800, '2964'],
#  [159800, '2964'],
#  [159800, '2202'],
#  [159800, '26612'],
#  [159800, '2964'],
#  [159800, '2061'],
#  [159800, '2202'],
#  [159800, '2202'],
#  [44987, '212'],
#  [44987, '13754'],
#  [44987, '28002'],
#  [44987, '20206'],
#  [184332, nan],
#  [91430, '157'],
#  [91430, '8558'],
#  [24235, '2207'],
#  [24235, '692'],
#  [24235, '551'],
#  [24235, '866'],
#  [24235, '4'],
#  [24235, '1054'],
#  [24235, '815'],
#  [24235, '815'],
#  [34975, '2900'],
#  [34975, '579'],
#  [34975, '2900'],
#  [34975, '2900'],
#  [34975, '2900'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [34975, '3025'],
#  [142009, '293'],
#  [142009, '2406'],
#  [128446, '1593'],
#  [128446, '2880'],
#  [128446, '2963'],
#  [91715, nan],
#  [122625, nan],
#  [168831, '571'],
#  [119384, nan],
#  [90123, nan],
#  [81033, '2084'],
#  [81033, '2758'],
#  [81033, '1040'],
#  [78053, nan],
#  [170568, '15040'],
#  [170568, '15040'],
#  [170568, '15040'],
#  [170568, '1952'],
#  [170568, '10145'],
#  [170568, '10145'],
#  [170568, '2050'],
#  [170568, '1297'],
#  [170568, '15040'],
#  [170568, '15040'],
#  [170568, '1191'],
#  [61609, '301'],
#  [61609, '290'],
#  [61609, '571'],
#  [61609, '2798'],
#  [61609, '2798'],
#  [61609, '182'],
#  [61609, '212'],
#  [61609, '212'],
#  [61609, '21584'],
#  [133929, nan],
#  [117321, nan],
#  [64872, '26627'],
#  [64872, '3118'],
#  [64872, '1136'],
#  [64872, '1136'],
#  [64872, '444'],
#  [96968, nan],
#  [170959, nan],
#  [178310, '2775'],
#  [178310, '114'],
#  [178310, '1636'],
#  [178310, '223'],
#  [53828, nan],
#  [10380, '74'],
#  [10380, '1848'],
#  [62979, nan],
#  [98605, '376'],
#  [98605, '215'],
#  [98605, '2087'],
#  [98605, '648'],
#  [98605, '1930'],
#  [98605, '3208'],
#  [98605, '403'],
#  [98605, '2182'],
#  [98605, '2746'],
#  [107820, nan],
#  [7536, nan],
#  [154166, nan],
#  [119438, '919'],
#  [119438, '919'],
#  [119438, '919'],
#  [150140, nan],
#  [161810, nan],
#  [119521, nan],
#  [19074, nan],
#  [95773, nan],
#  [58755, '2066'],
#  [58755, '2964'],
#  [58755, '2758'],
#  [58755, '2066'],
#  [136114, nan],
#  [191736, '2047'],
#  [191736, '2047'],
#  [116326, nan],
#  [81002, nan],
#  [128876, '507'],
#  [128876, '1925'],
#  [96440, nan],
#  [127319, '1487'],
#  [127319, '1136'],
#  [127319, '12429'],
#  [127319, '2588'],
#  [127319, '2628'],
#  [127319, '2727'],
#  [127319, '2300'],
#  [127319, '1901'],
#  [127319, '2207'],
#  [127319, '1334'],
#  [127319, '1033'],
#  [127319, '2107'],
#  [127319, '2059'],
#  [127319, '1557'],
#  [127319, '468'],
#  [127319, '2307'],
#  [127319, '2444'],
#  [127319, '732'],
#  [127319, '3131'],
#  [127319, '701'],
#  [127319, '1525'],
#  [86748, nan],
#  [152314, '1994'],
#  [152314, '1994'],
#  [152314, '1994'],
#  [152314, '287'],
#  [152314, '287'],
#  [152314, '735'],
#  [152314, '364'],
#  [152314, '27880'],
#  [152314, '2838'],
#  [152314, '2838'],
#  [152314, '2838'],
#  [152314, '2838'],
#  [152314, '1055'],
#  [152314, '2902'],
#  [152314, '13781'],
#  [152314, '13781'],
#  [152314, '3270'],
#  [152314, '22815'],
#  [152314, '22815'],
#  [152314, '6064'],
#  [152314, '6064'],
#  [152314, '22815'],
#  [152314, '1930'],
#  [152314, '21493'],
#  [152314, '995'],
#  [68418, '598'],
#  [68418, '1219'],
#  [68418, '1487'],
#  [68418, '972'],
#  [68418, '3321'],
#  [68418, '957'],
#  [68418, '1857'],
#  [68418, '238'],
#  [68418, '2087'],
#  [68418, '238'],
#  [56836, '648'],
#  [56836, '648'],
#  [56836, '648'],
#  [56836, '648'],
#  [56836, '758'],
#  [31092, '3121'],
#  [91147, nan],
#  [172934, nan],
#  [34187, '26670'],
#  [34187, '26670'],
#  [34187, '3202'],
#  [34187, '2085'],
#  [34187, '2788'],
#  [34187, '24605'],
#  [196672, nan],
#  [89765, '1583'],
#  [89765, '1583'],
#  [89765, '26677'],
#  [89765, '2103'],
#  [89765, '2013'],
#  [89765, '7321'],
#  [89765, '1942'],
#  [89765, '1218'],
#  [89765, '11736'],
#  [89765, '3081'],
#  [89765, '1583'],
#  [89765, '1583'],
#  [73251, nan],
#  [197717, '2509'],
#  [197717, '2509'],
#  [197717, '806'],
#  [197717, '341'],
#  [197717, '806'],
#  [197717, '1030'],
#  [96364, '3301'],
#  [96364, '6018'],
#  [96364, '3202'],
#  [96364, '1012'],
#  [96364, '13808'],
#  [96364, '2977'],
#  [96364, '1021'],
#  [96364, '201'],
#  [96364, '6074'],
#  [96364, '1886'],
#  [96364, '2339'],
#  [96364, '2498'],
#  [96364, '25331'],
#  [96364, '2107'],
#  [96364, '579'],
#  [96364, '855'],
#  [96364, '2344'],
#  [96364, '2307'],
#  [96364, '721'],
#  [96364, '25332'],
#  [96364, '2593'],
#  [51997, '2580'],
#  [51997, '2580'],
#  [51997, '2580'],
#  [51997, '182'],
#  [156621, '2344'],
#  [156621, '8573'],
#  [156621, '4772'],
#  [156621, '4772'],
#  [156621, '2344'],
#  [156621, '7321'],
#  [39685, nan],
#  [104481, '815'],
#  [104481, '15095'],
#  [104481, '15095'],
#  [104481, '16379'],
#  [104481, '16322'],
#  [197368, nan],
#  [63494, nan],
#  [118084, '3254'],
#  [118084, '295'],
#  [118084, '884'],
#  [118084, '1674'],
#  [80464, nan],
#  [14032, '2366'],
#  [14032, '149'],
#  [14032, '3097'],
#  [14032, '2084'],
#  [14032, '2084'],
#  [54335, nan],
#  [13266, '1578'],
#  [13266, '1578'],
#  [13266, '7412'],
#  [13266, '2587'],
#  [57746, '1487'],
#  [57746, '1487'],
#  [57746, '1487'],
#  [34835, nan],
#  [142691, '1979'],
#  [142691, '1579'],
#  [142691, '1579'],
#  [142691, '1579'],
#  [131910, nan],
#  [8081, nan],
#  [4125, nan],
#  [49714, nan],
#  [29267, '1745'],
#  [29267, '17628'],
#  [29267, '19299'],
#  [29267, '27909'],
#  [29267, '25471'],
#  [29267, '22826'],
#  [29267, '15629'],
#  [29267, '7671'],
#  [29267, '8672'],
#  [29267, '17918'],
#  [29267, '11516'],
#  [29267, '17662'],
#  [29267, '25324'],
#  [29267, '20420'],
#  [29267, '24049'],
#  [29267, '12405'],
#  [5727, nan],
#  [115194, '1049'],
#  [115194, '886'],
#  [115194, '688'],
#  [115194, '1030'],
#  [115194, '2535'],
#  [115194, '1302'],
#  [115194, '516'],
#  [115194, '3207'],
#  [124263, '2636'],
#  [82506, '942'],
#  [82506, '184'],
#  [82506, '2063'],
#  [82506, '1927'],
#  [82506, '812'],
#  [82506, '1776'],
#  [182711, nan],
#  [60358, nan],
#  [195817, '1770'],
#  [195817, '668'],
#  [195817, '734'],
#  [195817, '1553'],
#  [195817, '12500'],
#  [195817, '509'],
#  [195817, '13919'],
#  [195817, '10467'],
#  [195817, '481'],
#  [195817, '1171'],
#  [195817, '1171'],
#  [195817, '1171'],
#  [106649, nan],
#  [53422, '2107'],
#  [53422, '1860'],
#  [180743, nan],
#  [109661, '2834'],
#  [109661, '1954'],
#  [132187, '2100'],
#  [132187, '2648'],
#  [132187, '558'],
#  [160490, nan],
#  [184440, nan],
#  [120516, '341'],
#  [120516, '751'],
#  [120516, '1487'],
#  [120516, '1487'],
#  [16057, '2567'],
#  [16057, '2063'],
#  [16057, '1178'],
#  [16057, '1178'],
#  [16057, '85'],
#  [16057, '2580'],
#  [61788, '3314'],
#  [61788, '3314'],
#  [61788, '169'],
#  [61788, '3139'],
#  [61788, '2977'],
#  [61788, '3301'],
#  [61788, '7377'],
#  [61788, '2018'],
#  [61788, '2621'],
#  [61788, '1514'],
#  [61788, '1514'],
#  [61788, '708'],
#  [61788, '13747'],
#  [61788, '2339'],
#  [61788, '789'],
#  [61788, '201'],
#  [61788, '884'],
#  [61788, '1835'],
#  [61788, '708'],
#  [61788, '3028'],
#  [115068, '18854'],
#  [115068, '15067'],
#  [115068, '2214'],
#  [115068, '403'],
#  [115068, '22786'],
#  [115068, '2765'],
#  [115068, '1033'],
#  [115068, '12'],
#  [115068, '22786'],
#  [115068, '22786'],
#  [115068, '22786'],
#  [115068, '22786'],
#  [115068, '16379'],
#  [115068, '215'],
#  [115068, '15630'],
#  [115068, '16379'],
#  [174603, nan],
#  [180371, nan],
#  [51283, nan],
#  [124342, '1782'],
#  [124342, '1487'],
#  [124342, '3202'],
#  [124342, '1518'],
#  [124342, '18865'],
#  [124342, '22769'],
#  [124342, '2498'],
#  [124342, '25615'],
#  [27247, '945'],
#  [27247, '945'],
#  [154652, '539'],
#  [154652, '2322'],
#  [154652, '2322'],
#  [69008, '154'],
#  [69008, '154'],
#  [46689, nan],
#  [160604, nan],
#  [44561, nan],
#  [130976, '1010'],
#  [130976, '2243'],
#  [130976, '6037'],
#  [130976, '996'],
#  [130976, '1926'],
#  [130976, '700'],
#  [130976, '2000'],
#  [160784, '154'],
#  [160784, '154'],
#  [160784, '18857'],
#  [160784, '27866'],
#  [160784, '18857'],
#  [188463, '1162'],
#  [188463, '1162'],
#  [188463, '1162'],
#  [188463, '571'],
#  [129500, nan],
#  [125548, nan],
#  [198585, '26866'],
#  [198585, '20234'],
#  [37045, '1239'],
#  [37045, '1239'],
#  [194871, nan],
#  [149267, nan],
#  [101588, '18845'],
#  [101588, '2998'],
#  [101588, '1906'],
#  [101588, '2307'],
#  [101588, '2998'],
#  [101588, '2580'],
#  [101588, '2532'],
#  [101588, '2580'],
#  [101588, '2964'],
#  [101588, '2307'],
#  [20453, nan],
#  [58237, '2741'],
#  [58237, '3270'],
#  [17603, nan],
#  [138065, nan],
#  [25538, '914'],
#  [139953, nan],
#  [132590, nan],
#  [183522, nan],
#  [112557, nan],
#  [66729, '603'],
#  [66729, '603'],
#  [8859, nan],
#  [54768, nan],
#  [40494, '770'],
#  [40494, '13889'],
#  [40494, '2406'],
#  [40494, '2406'],
#  [40494, '145'],
#  [40494, '1971'],
#  [40494, '2598'],
#  [40494, '2598'],
#  [86133, '2087'],
#  [86133, '22786'],
#  [86133, '5037'],
#  [86133, '18865'],
#  [86133, '1469'],
#  [86133, '1469'],
#  [86133, '2254'],
#  [86133, '22786'],
#  [76423, '688'],
#  [76423, '688'],
#  [76423, '985'],
#  [76423, '688'],
#  [4899, '3247'],
#  [4899, '304'],
#  [45066, nan],
#  [114157, '2427'],
#  [114157, '2295'],
#  [116275, nan],
#  [51345, nan],
#  [184792, '2779'],
#  [184792, '2972'],
#  [184792, '7338'],
#  [184792, '541'],
#  [101430, nan],
#  [88019, '754'],
#  [88019, '754'],
#  [88019, '754'],
#  [88019, '754'],
#  [88019, '1487'],
#  [88019, '1297'],
#  [88019, '4813'],
#  [88019, '4813'],
#  [85840, '2053'],
#  [85840, '2053'],
#  [85840, '218'],
#  [85840, '2498'],
#  [85840, '821'],
#  [85840, '1194'],
#  [85840, '2864'],
#  [85840, '2864'],
#  [85840, '2864'],
#  [85840, '821'],
#  [85840, '1327'],
#  [85840, '2864'],
#  [85840, '1218'],
#  [85840, '1193'],
#  [85840, '22030'],
#  [85840, '2977'],
#  [85840, '1707'],
#  [155668, '2777'],
#  [155668, '26601'],
#  [64513, '525'],
#  [64513, '525'],
#  [64513, '3076'],
#  [64513, '419'],
#  [64513, '1837'],
#  [64513, '3008'],
#  [64513, '1518'],
#  [64513, '419'],
#  [177835, '2080'],
#  [177835, '761'],
#  [177835, '3278'],
#  [177835, '2996'],
#  [177835, '441'],
#  [177835, '945'],
#  [177835, '945'],
#  [177835, '3278'],
#  [2533, '2977'],
#  [2533, '2509'],
#  [2533, '20206'],
#  [2533, '20206'],
#  [2533, '20206'],
#  [2533, '20206'],
#  [51251, '1550'],
#  [51251, '1802'],
#  [51251, '216'],
#  [51251, '216'],
#  [51251, '3302'],
#  [51251, '3302'],
#  [51251, '3306'],
#  [51251, '1452'],
#  [51251, '1452'],
#  [42490, nan],
#  [46205, '22'],
#  [46205, '403'],
#  [46205, '830'],
#  [46205, '830'],
#  [46205, '3047'],
#  [46205, '3047'],
#  [46205, '56'],
#  [46205, '56'],
#  [46205, '56'],
#  [46205, '56'],
#  [46205, '83'],
#  [46205, '182'],
#  [46205, '2108'],
#  [123649, '122'],
#  [123649, '122'],
#  [49691, nan],
#  [88358, nan],
#  [25381, '1644'],
#  [25381, '3211'],
#  [25381, '3211'],
#  [190916, '2403'],
#  [190916, '2569'],
#  [190916, '603'],
#  [190916, '2344'],
#  [190916, '489'],
#  [190916, '1925'],
#  [190916, '1578'],
#  [6198, '2284'],
#  [6198, '1373'],
#  [65616, '2018'],
#  [65616, '1372'],
#  [65616, '12547'],
#  [65616, '3054'],
#  [65616, '2018'],
#  [89505, '1733'],
#  [89505, '757'],
#  [16964, '2888'],
#  [16964, '1363'],
#  [16964, '1363'],
#  [16964, '1363'],
#  [150692, nan],
#  [130488, '3031'],
#  [130488, '3008'],
#  [197048, nan],
#  [37028, '821'],
#  [37028, '157'],
#  [37028, '821'],
#  [37028, '821'],
#  [188191, nan],
#  [111248, '9156'],
#  [111248, '24592'],
#  [111248, '11724'],
#  [111248, '2509'],
#  [111248, '240'],
#  [111248, '972'],
#  [111248, '240'],
#  [121178, nan],
#  [111936, nan],
#  [152335, nan],
#  [123487, nan],
#  [122381, '593'],
#  [122381, '490'],
#  [122381, '8565'],
#  [122381, '2596'],
#  [122381, '2538'],
#  [122381, '2389'],
#  [119845, nan],
#  [48282, '157'],
#  [48282, '2344'],
#  [48282, '2621'],
#  [56158, '3230'],
#  ...]

# %%
for user_click in user_click_list:
    i[0]
    i[1]

# %% [markdown]
# ## 2.3 Geo Relation

# %% [markdown]
# ## 2.4 Integrating the 3 Recall Method

# %%
intg_poi_4_user_idct = top_poi_4_user_dict
intg_poi_4_user_idct = defaultdict(list)
for user_click in user_click_list:
    if user_click[1] not in intg_poi_4_user_idct[user_click[0]]:
        intg_poi_4_user_idct[user_click[0]].append(user_click[1])

# %%
# Check Hit Radio Performance

test_pairs_pos = orders_test.values.tolist()

poi_hit = 0
poi_num = 0

for test_pair_index in range(10000):
    pos_pois = pos_pairs_dict_test[test_pair_index].keys()
    
    for poi_index in pos_pois:
        poi_num += 1
        if poi_index in intg_poi_4_user_idct[test_pair_index]:
            poi_hit += 1

hit_ratio = poi_hit/poi_num

# %%
poi_hit
# Out:
# 0

# %% [markdown]
# # 3 Geo Filtering

# %%
pos_geo_pair = orders_train[['aor_id','aoi_id']]
pos_geo_pair = poi_user_pos_geo_pair.dropna(axis=0)
pos_geo_pair['aoi_id'] = poi_user_pos_geo_pair['aoi_id'].astype('int')
pos_geo_pair = pos_geo_pair.groupby(['aor_id','aoi_id'], as_index=False).size()

# %%
pos_geo_pair_sort = pos_geo_pair.sort_values('size', ascending=False)

# %%
pos_geo_pair_sort.values.tolist()[1578]
# Out:
# [1, 1906, 111]

# %%
pos_geo_pair_filtered = pos_geo_pair_sort[pos_geo_pair_sort['size'] >= 200]

# %%
pos_geo_pair_filtered
# Out:
#       aor_id  aoi_id   size
# 170        0     208  12392
# 3663       5     223   7335
# 2487       3     373   5910
# 4165       6       1   5532
# 236        0     302   5110
# ...      ...     ...    ...
# 7408      10     958    201
# 7427      10     977    201
# 4279       6     115    201
# 7330      10     871    200
# 7213      10     754    200
#
# [1146 rows x 3 columns]

# %%
pos_geo_pair_valid = pos_geo_pair_filtered[['aor_id','aoi_id']].values.tolist()

# %%
for user in intg_poi_4_user_idct.keys():
    for poi in intg_poi_4_user_idct[user]:
        poi_aor = int(10000 if pd.isnull(pois[pois['wm_poi_id']==poi]['aor_id']) else pois[pois['wm_poi_id']==poi]['aor_id'])
        user_aoi = int(orders_train[orders_train['user_id']==user]['aoi_id'][0])
        
        if [user, poi] not in pos_geo_pair_valid:
            del intg_poi_4_user_idct[user][poi]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\AXE-YU~1\AppData\Local\Temp/ipykernel_19496/2253803661.py in <module>
#       1 for user in intg_poi_4_user_idct.keys():
#       2     for poi in intg_poi_4_user_idct[user]:
# ----> 3         poi_aor = int(10000 if pd.isnull(pois[pois['wm_poi_id']==poi]['aor_id']) else pois[pois['wm_poi_id']==poi]['aor_id'])
#       4         user_aoi = int(orders_train[orders_train['user_id']==user]['aoi_id'][0])
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
users
# Out:
#         user_id avg_pay_amt avg_pay_amt_weekdays avg_pay_amt_weekends
# 0             0     [36,49)              [29,36)              [36,49)
# 1             1     [49,65)              [49,65)                 >=65
# 2             2         <29                  <29                  <29
# 3             3     [49,65)                 >=65              [49,65)
# 4             4     [36,49)                   未知              [49,65)
# ...         ...         ...                  ...                  ...
# 199995   199995     [36,49)              [36,49)              [36,49)
# 199996   199996        >=65                 >=65              [49,65)
# 199997   199997     [36,49)              [36,49)              [36,49)
# 199998   199998         <29                  <29                  <29
# 199999   199999         <29                  <29                  <29
#
# [200000 rows x 4 columns]

# %%
sum(pois['aor_id']==10000)
# Out:
# 0
